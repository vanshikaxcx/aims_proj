# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install transformers tokenizers
# !pip install timm
# !pip install supervision
# !pip install pycocotools
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.3 MB/s eta 0:00:00
# ...

# %%
# Create the data directory
# !mkdir -p data/coco

# Download training images (This is a large file: ~18GB)
# !wget -P data/coco/ http://images.cocodataset.org/zips/train2017.zip

# Download annotations
# !wget -P data/coco/ http://images.cocodataset.org/annotations/annotations_train2017.zip

# Unzip the files
# !unzip data/coco/train2017.zip -d data/coco/
# !unzip data/coco/annotations_train2017.zip -d data/coco/
# Out:
# --2025-08-15 17:58:20--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 16.15.217.51, 52.216.184.219, 52.217.93.212, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|16.15.217.51|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘data/coco/train2017.zip’
#
# train2017.zip         7%[>                   ]   1.43G  58.9MB/s    eta 4m 50s

# %%
# !touch src/model.py src/dataset.py src/train.py src/inference.py

# %%
# !python src/train.py
# Out:
# Traceback (most recent call last):
#   File "/content/src/train.py", line 6, in <module>
#     from src.dataset import CocoGroundingDataset
# ModuleNotFoundError: No module named 'src'

# %%
# !python -m src.train
# Out:
# 2025-08-14 22:14:03.404670: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755209643.424553    8876 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755209643.430870    8876 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755209643.446803    8876 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls -l /content/data/coco/annotations/
# Out:
# ls: cannot access '/content/data/coco/annotations/': No such file or directory

# %%
# !ls -l /content/data/coco/
# Out:
# total 18887716
# drwxrwxr-x 2 root root     4141056 Aug 31  2017 train2017
# -rw-r--r-- 1 root root 19336861798 Jul 11  2018 train2017.zip

# %%
# !unzip /content/data/coco/annotations_train2017.zip -d /content/data/coco/
# Out:
# unzip:  cannot find or open /content/data/coco/annotations_train2017.zip, /content/data/coco/annotations_train2017.zip.zip or /content/data/coco/annotations_train2017.zip.ZIP.

# %%
# Download annotations again
# !wget -P data/coco/ http://images.cocodataset.org/annotations/annotations_train2017.zip

# Unzip the annotations file
# !unzip data/coco/annotations_train2017.zip -d data/coco/
# Out:
# --2025-08-14 22:17:52--  http://images.cocodataset.org/annotations/annotations_train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.130.161, 16.15.180.42, 52.216.208.17, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.130.161|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-08-14 22:17:52 ERROR 404: Not Found.
#
# unzip:  cannot find or open data/coco/annotations_train2017.zip, data/coco/annotations_train2017.zip.zip or data/coco/annotations_train2017.zip.ZIP.

# %%
# !ls /content/
# Out:
# data  sample_data  src

# %%
# !wget -P /content/data/coco/ http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2025-08-14 22:21:15--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.16.156, 3.5.10.112, 54.231.235.153, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.16.156|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘/content/data/coco/annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  55.0MB/s    in 4.9s
#
# 2025-08-14 22:21:20 (49.7 MB/s) - ‘/content/data/coco/annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# !unzip /content/data/coco/annotations_trainval2017.zip -d /content/data/coco/
# Out:
# Archive:  /content/data/coco/annotations_trainval2017.zip
#   inflating: /content/data/coco/annotations/instances_train2017.json
#   inflating: /content/data/coco/annotations/instances_val2017.json
#   inflating: /content/data/coco/annotations/captions_train2017.json
#   inflating: /content/data/coco/annotations/captions_val2017.json
#   inflating: /content/data/coco/annotations/person_keypoints_train2017.json
#   inflating: /content/data/coco/annotations/person_keypoints_val2017.json

# %%
# !python -m src.train
# Out:
# 2025-08-14 22:28:04.087194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755210484.107294   12457 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755210484.113645   12457 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755210484.129706   12457 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !wget -O test_image.jpg https://images.unsplash.com/photo-1599420186946-7b6fb4e297f0
# Out:
# --2025-08-14 23:19:47--  https://images.unsplash.com/photo-1599420186946-7b6fb4e297f0
# Resolving images.unsplash.com (images.unsplash.com)... 151.101.2.208, 151.101.66.208, 151.101.130.208, ...
# Connecting to images.unsplash.com (images.unsplash.com)|151.101.2.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9386358 (9.0M) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]   8.95M  --.-KB/s    in 0.06s
#
# 2025-08-14 23:19:47 (145 MB/s) - ‘test_image.jpg’ saved [9386358/9386358]

# %%
# !python src/inference.py
# Out:
# 2025-08-14 23:27:38.151441: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755214058.171666   27340 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755214058.177973   27340 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755214058.194394   27340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !touch src/interactive_inference.py

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-45bj3n9h
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-45bj3n9h
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done

# %%
from src.sam_inference import display_ui
display_ui()
# Out:
# Loading Grounding DINO model...
# Grounding DINO loaded.
# Loading SAM model...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-547225307.py in <cell line: 0>()
# ----> 1 from src.sam_inference import display_ui
#       2 display_ui()
#
# /content/src/sam_inference.py in <module>
#      24
#      25 print("Loading SAM model...")
# ---> 26 sam = sam_model_registry[SAM_MODEL_TYPE](checkpoint=SAM_CHECKPOINT).to(device=DEVICE)
#      27 sam_predictor = SamPredictor(sam)
#      28 print("SAM loaded.")
#
# /usr/local/lib/python3.11/dist-packages/segment_anything/build_sam.py in build_sam_vit_h(checkpoint)
#      13
#      14 def build_sam_vit_h(checkpoint=None):
# ---> 15     return _build_sam(
#      16         encoder_embed_dim=1280,
#      17         encoder_depth=32,
#
# ...

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# --2025-08-14 23:50:57--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.163.189.96, 3.163.189.108, 3.163.189.14, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.163.189.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth.1’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G   268MB/s    in 13s
#
# 2025-08-14 23:51:09 (194 MB/s) - ‘sam_vit_h_4b8939.pth.1’ saved [2564550879/2564550879]

# %%
from src.sam_inference import display_ui
display_ui()
# Out:
# Loading Grounding DINO model...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Grounding DINO loaded.
# Loading SAM model...
# SAM loaded.
# ...

# %%
# Install the SAM library
# !pip install git+https://github.com/facebookresearch/segment-anything.git

# Download the SAM model checkpoint
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-d0jwdmct
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-d0jwdmct
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# --2025-08-14 23:58:15--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.163.189.108, 3.163.189.14, 3.163.189.51, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.163.189.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth.2’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G  83.4MB/s    in 31s
#
# ...

# %%
from src.sam_inference import display_ui
display_ui()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0153934d-27da-4b67-9bd5-66fc9940abf2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0153934d-27da-4b67-9bd5-66fc9940abf2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# This will take a minute or two to complete
# !rm -rf /content/data/coco/train2017
# !rm -rf /content/data/coco/train2017.zip
